# %% [markdown]
# ### Import the library

# %%
import pandas as pd
import numpy as np
import time
import requests

# %% [markdown]
# ### Download the data##

# %%
def recap(year,day):
    
    #seed = np.random.randint(low = 2,high = 5, size = 1)
    #seed = int(seed)
    time.sleep(1)    
    
    headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36', "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8","accept-encoding":"gzip, deflate, br","accept-language":"en-US;q=0.6,en;q=0.4,zh-TW,zh;q=0.8,zh-CN;q=0.2"}
    session = requests.Session()
    re = session.get("https://www.wunderground.com/history/airport/KNYC/{}/1/{}/DailyHistory.html?req_city=&req_state=&req_statename=&reqdb.zip=&reqdb.magic=&reqdb.wmo=&MR=1".format(year,day), headers = headers)
    
    df = pd.read_html(re.content)[4]
    df["Date"] = pd.read_html(re.content)[2].columns[0]
    
    return df

# %% [markdown]
# ### Merge the data
# __(PS: Do not run this code, unless you need it, it will cost approximately 30 mins to run the whole year)__

# %%
df_yr = pd.DataFrame()
t0 = time.time()
j = 0
for year in range(2013,2017):
    for i in range(1,366):
        df_day = recap(year,i)
        df_yr = pd.concat([df_yr,df_day], axis=0, ignore_index=True)
        j = j + 1
        if j == 30:
            print("30 days finish")
            j = 0
    print(year)

t1 = time.time()-t0
df_yr
# Out:
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 2013
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 2014
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 2015
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 30 days finish
# 2016
#              Conditions           Date Dew Point        Events Gust Speed  \
# 0              Overcast  Jan. 01, 2013   24.1 °F           NaN   21.9 mph
# ...

# %% [markdown]
# ### Save as CSV

# %%
df_yr.to_csv("2013to2016_weather.csv")

# %%
print("it take ", int(t1/60), "mins")
# Out:
# it take  68 mins

# %%
df = pd.read_html(re.content)[4]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ed2c655e46b9> in <module>()
# ----> 1 df = pd.read_html(re.content)[4]
#       2 df
#
# NameError: name 're' is not defined

# %%
df = pd.read_csv("2013to2016_weather.csv")
df
# Out:
#        Unnamed: 0        Conditions           Date Dew Point        Events  \
# 0               0          Overcast  Jan. 01, 2013   24.1 °F           NaN
# 1               1          Overcast  Jan. 01, 2013   26.1 °F           NaN
# 2               2          Overcast  Jan. 01, 2013   27.0 °F           NaN
# 3               3          Overcast  Jan. 01, 2013   27.0 °F           NaN
# 4               4          Overcast  Jan. 01, 2013   27.0 °F           NaN
# 5               5          Overcast  Jan. 01, 2013   26.1 °F           NaN
# 6               6          Overcast  Jan. 01, 2013   26.1 °F           NaN
# 7               7          Overcast  Jan. 01, 2013   27.0 °F           NaN
# 8               8          Overcast  Jan. 01, 2013   27.0 °F           NaN
# 9               9     Partly Cloudy  Jan. 01, 2013   27.0 °F           NaN
# 10             10          Overcast  Jan. 01, 2013   27.0 °F           NaN
# ...
